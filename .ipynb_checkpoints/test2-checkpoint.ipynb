# %%
# import required module
import numpy as np
import pandas as pd
from scipy import signal
import os
import matplotlib.pyplot as plt
import pandas as pd
from scipy.fft import fft, ifft

# assign directory
tick = 0
directory = 'data'
fs = 2000
Gmax = 0
disp_max = 0
tmax = 0
delta_t = 1.0/fs
T = []
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
        print(f)
    trace = np.fromfile(f, dtype="float32")
    time = list(range(0, len(trace)))
    Gmax = max(Gmax, np.max(np.abs(trace[200:])))
    tmax = max(tmax, len(trace))
       
    plt.plot((trace))
    plt.axis([-500, tmax+250, -np.max(np.abs(trace[200:]))-0.5,  np.max(np.abs(trace[200:]))+2])
    plt.xlabel("Time, T")
    plt.ylabel("Acc. [G]")

    
    
    # get the frequency and spectrum
    f, Pxx = signal.periodogram(trace, fs = fs, scaling='spectrum')
        
    # get the autocorrelation coefficient
    acf = sm.tsa.acf(trace, nlags=len(trace))
    lag = np.arange(len(trace)) / fs
   
    
    T.append(lag[np.argsort(np.abs(acf))[::-1][1:2]])
        

print(T)
# Out:
# data\20180425_073205_078754_001_channel1.dat
# data\20180425_122814_078960_001_channel1.dat
# data\20180427_190457_078622_001_channel1.dat
# data\20180427_193039_078622_001_channel1.dat
# data\20180429_103211_078630_001_channel1.dat
# data\20180429_104940_082863_001_channel1.dat
# data\20180429_133609_101648_001_channel1.dat
# data\20180430_055543_101630_001_channel1.dat
# data\20180430_083806_078770_001_channel1.dat
# data\20180430_092204_078630_001_channel1.dat
# data\20180430_180610_078747_001_channel1.dat
# data\20180430_193907_078747_001_channel1.dat
# data\20180501_081506_078754_001_channel1.dat
# data\20180501_103307_101648_001_channel1.dat
# data\20180502_080544_078663_001_channel1.dat
# data\20180502_201527_101630_001_channel1.dat
# data\20180503_051716_078754_001_channel1.dat
# data\20180504_112009_078663_001_channel1.dat
# data\20180504_125651_078796_001_channel1.dat
# data\20180505_165351_078770_001_channel1.dat
# ...

# %%
window_size = 25
  
# Convert array of integers to pandas series
numbers_series = pd.Series(trace)
  
# Get the window of series
# of observations of specified window size
windows = numbers_series.rolling(window_size)
  
# Create a series of moving
# averages of each window
moving_averages = windows.mean()
  
# Convert pandas series back to list
moving_averages_list = moving_averages.tolist()
  
# Remove null entries from the list
final_list = moving_averages_list[window_size - 1:]
plt.plot(trace)
plt.plot(final_list)

# %%
10000/13/2000
# Out:
# 0.38461538461538464

# %%
T = []
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
        print(f)
    trace = np.fromfile(f, dtype="float32")
    time = list(range(0, len(trace)))
    Gmax = max(Gmax, np.max(np.abs(trace[200:])))
    tmax = max(tmax, len(trace))
    
    window_size = 25
  
    # Convert array of integers to pandas series
    numbers_series = pd.Series(trace)

    # Get the window of series
    # of observations of specified window size
    windows = numbers_series.rolling(window_size)

    # Create a series of moving
    # averages of each window
    moving_averages = windows.mean()

    # Convert pandas series back to list
    moving_averages_list = moving_averages.tolist()

    # Remove null entries from the list
    final_list = moving_averages_list[window_size - 1:]
    plt.plot(trace)
    plt.plot(final_list)
    plt.axis([-500, tmax+250, -np.max(np.abs(trace[200:]))-0.5,  np.max(np.abs(trace[200:]))+2])
    plt.xlabel("Time, T")
    plt.ylabel("Acc. [G]")
    plt.show()
    
    # get the frequency and spectrum
    f, Pxx = signal.periodogram(np.abs(trace), fs = fs, scaling='spectrum')
        
    # get the autocorrelation coefficient
    acf = sm.tsa.acf(np.abs(trace), nlags=len(trace))
    lag = np.arange(len(trace)) / fs
   
    
    T.append(lag[np.argsort(np.abs(acf))[::-1][2]])
    print(T)
# Out:
# data\20180425_073205_078754_001_channel1.dat
# [0.001]
# data\20180425_122814_078960_001_channel1.dat
# [0.001, 0.001]
# data\20180427_190457_078622_001_channel1.dat
# [0.001, 0.001, 0.001]
# data\20180427_193039_078622_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001]
# data\20180429_103211_078630_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001]
# data\20180429_104940_082863_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001]
# data\20180429_133609_101648_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001]
# data\20180430_055543_101630_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.0015]
# data\20180430_083806_078770_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.0015, 0.001]
# data\20180430_092204_078630_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.0015, 0.001, 0.001]
# data\20180430_180610_078747_001_channel1.dat
# ...

# %%
T = []
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
        print(f)
    trace = np.abs(np.fromfile(f, dtype="float32"))
    time = list(range(0, len(trace)))
    Gmax = max(Gmax, np.max(np.abs(trace[200:])))
    tmax = max(tmax, len(trace))
    
    window_size = 25
  
    # Convert array of integers to pandas series
    numbers_series = pd.Series(trace)

    # Get the window of series
    # of observations of specified window size
    windows = numbers_series.rolling(window_size)

    # Create a series of moving
    # averages of each window
    moving_averages = windows.mean()

    # Convert pandas series back to list
    moving_averages_list = moving_averages.tolist()

    # Remove null entries from the list
    final_list = moving_averages_list[window_size - 1:]
    plt.plot(trace)
    plt.plot(final_list)
    plt.axis([-500, tmax+250, -np.max(np.abs(trace[200:]))-0.5,  np.max(np.abs(trace[200:]))+2])
    plt.xlabel("Time, T")
    plt.ylabel("Acc. [G]")
    plt.show()
    
    # get the frequency and spectrum
    f, Pxx = signal.periodogram(np.abs(trace), fs = fs, scaling='spectrum')
    
    # get the autocorrelation coefficient
    acf = sm.tsa.acf(np.abs(trace), nlags=len(trace))
    lag = np.arange(len(trace)) / fs
   
    
    T.append(lag[np.argsort(np.abs(acf))[::-1][2]])
    print(T)
# Out:
# data\20180425_073205_078754_001_channel1.dat
# [0.001]
# data\20180425_122814_078960_001_channel1.dat
# [0.001, 0.001]
# data\20180427_190457_078622_001_channel1.dat
# [0.001, 0.001, 0.001]
# data\20180427_193039_078622_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001]
# data\20180429_103211_078630_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001]
# data\20180429_104940_082863_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001]
# data\20180429_133609_101648_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001]
# data\20180430_055543_101630_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.0015]
# data\20180430_083806_078770_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.0015, 0.001]
# data\20180430_092204_078630_001_channel1.dat
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.0015, 0.001, 0.001]
# data\20180430_180610_078747_001_channel1.dat
# ...

# %%
samplingFrequency  = fs
fourierTransform = np.fft.fft(trace[200:])/len(trace)
fourierTransform = fourierTransform[range(int(len(trace)/2))]
tpCount     = len(trace)
values      = np.arange(int(tpCount/2))
timePeriod  = tpCount/samplingFrequency
frequencies = values/timePeriod
plt.plot(frequencies, abs(fourierTransform))
print(frequencies[np.argmax(fourierTransform)]/fs)
# Out:
# 0.0

# %%
from numpy import sin, linspace, pi
from pylab import plot, show, title, xlabel, ylabel, subplot
from scipy import fft, arange

def plotSpectrum(y,Fs):
    """
    Plots a Single-Sided Amplitude Spectrum of y(t)
    """
    n = len(y) # length of the signal
    k = arange(n)
    T = n/Fs
    frq = k/T # two sides frequency range
    frq = frq[range(n)] # one side frequency range

    Y = np.fft.fft(y)/n # fft computing and normalization
    Y = Y[range(n)]

    plot(frq,abs(Y),'r') # plotting the spectrum
    xlabel('Freq (Hz)')
    ylabel('|Y(freq)|')
    return Y

Fs = 2000;  # sampling rate
Ts = 1.0/Fs; # sampling interval

subplot(2,1,1)
plot(time,trace)
xlabel('Time')
ylabel('Amplitude')
subplot(2,1,2)
print(np.argmax(plotSpectrum(trace[200:len(trace)-200],Fs)))
show()
# Out:
# 0
# C:\Users\shkla\AppData\Local\Temp\ipykernel_8316\2417787960.py:10: DeprecationWarning: scipy.arange is deprecated and will be removed in SciPy 2.0.0, use numpy.arange instead
#   k = arange(n)

# %%
sampling_rate = fs

time = time

data = trace

fourier_transform = np.fft.rfft(data)

abs_fourier_transform = np.abs(fourier_transform)

power_spectrum = np.square(abs_fourier_transform)

frequency = np.linspace(0, sampling_rate/2, len(power_spectrum))

plt.plot(frequency, power_spectrum)

# %%
data = loadmat('matfiles/EEG-1.mat')  # Load the EEG data
EEG = data['EEG'].reshape(-1)         # Extract the EEG variable
t = data['t'][0]                      # ... and the t variable

x = EEG                               # Relabel the data variable
dt = t[1] - t[0]                      # Define the sampling interval
N = x.shape[0]                        # Define the total number of data points
T = N * dt                            # Define the total duration of the data

xf = fft(x - x.mean())                # Compute Fourier transform of x
Sxx = 2 * dt ** 2 / T * (xf * xf.conj())  # Compute spectrum
Sxx = Sxx[:int(len(x) / 2)]           # Ignore negative frequencies

df = 1 / T.max()                      # Determine frequency resolution
fNQ = 1 / dt / 2                      # Determine Nyquist frequency
faxis = arange(0,fNQ,df)              # Construct frequency axis

plot(faxis, Sxx.real)                 # Plot spectrum vs frequency
xlim([0, 100])                        # Select frequency range
xlabel('Frequency [Hz]')              # Label the axes
ylabel('Power [$\mu V^2$/Hz]')
show()
